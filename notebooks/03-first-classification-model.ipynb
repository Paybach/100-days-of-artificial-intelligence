# %% [markdown]
# # Notebook 03: First Classification Model
#
# Use this workbook during Days 021-030. Train a small classifier, inspect its predictions, and explain what the metrics mean.

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import train_test_split

iris = load_iris(as_frame=True)
features = iris.data
target = iris.target
features.head()

# %%
x_train, x_test, y_train, y_test = train_test_split(
    features,
    target,
    test_size=0.2,
    random_state=42,
    stratify=target,
)

model = LogisticRegression(max_iter=300)
model.fit(x_train, y_train)
predictions = model.predict(x_test)
print(classification_report(y_test, predictions, target_names=iris.target_names))

# %% [markdown]
# ## Exercises
#
# 1. Display a confusion matrix.
# 2. Count incorrect predictions.
# 3. Change `random_state` and rerun the notebook. What changes?
# 4. Remove one feature column and compare the result.
# 5. Explain precision and recall in your own words.
# 6. Write down one limitation of using this tiny dataset.

# %%
# TODO: display the confusion matrix and inspect incorrect predictions.

# %% [markdown]
# ## Reflection
#
# - Precision means: TODO
# - Recall means: TODO
# - One limitation is: TODO

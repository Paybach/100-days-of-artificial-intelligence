# %% [markdown]
# # Notebook 01: Python and NumPy Practice
#
# Use this workbook during Days 003-004. Run each cell, complete the TODOs, and write a short reflection before committing your work.

# %%
import numpy as np

daily_learning_minutes = np.array([35, 50, 45, 70, 30, 90, 55])
daily_learning_minutes

# %% [markdown]
# ## Exercises
#
# 1. Print the total learning time.
# 2. Calculate the average learning time.
# 3. Select the days where you studied for at least 50 minutes.
# 4. Add an eighth day to the array.
# 5. Create a second array containing a focus score from 1-5 for each day.
# 6. Write one sentence explaining whether time spent and focus appear related.

# %%
# TODO: complete Exercises 1-4 here.

# %%
# TODO: create your focus-score array and compare it with learning time.

# %% [markdown]
# ## Reflection
#
# Write three things you learned about NumPy arrays:
#
# - TODO
# - TODO
# - TODO

# %% [markdown]
# # Notebook 02: pandas Data Story
#
# Use this workbook during Days 005-009. Your goal is to turn a tiny dataset into a clear, evidence-based story.

# %%
import matplotlib.pyplot as plt
import pandas as pd

records = {
    "day": ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"],
    "topic": ["Python", "Python", "NumPy", "pandas", "pandas", "Charts", "Review"],
    "minutes": [35, 50, 45, 70, 30, 90, 55],
    "confidence": [2, 3, 3, 4, 3, 4, 4],
}

learning = pd.DataFrame(records)
learning

# %% [markdown]
# ## Exercises
#
# 1. Use `describe()` to summarize the numeric columns.
# 2. Filter the rows where `minutes` is greater than 45.
# 3. Group by `topic` and calculate total minutes.
# 4. Create a bar chart showing minutes by day.
# 5. Add a column named `long_session` that is `True` when minutes is at least 60.
# 6. Write two findings in plain English.

# %%
# TODO: summarize, filter, and group the data.

# %%
# TODO: create your chart and label the axes clearly.

# %% [markdown]
# ## Findings
#
# 1. TODO
# 2. TODO

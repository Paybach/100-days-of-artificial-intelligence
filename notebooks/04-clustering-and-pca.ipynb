# %% [markdown]
# # Notebook 04: Clustering and PCA
#
# Use this workbook during Days 031-040. Explore unsupervised learning and compare cluster choices visually.

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import load_wine
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

wine = load_wine(as_frame=True)
scaled_features = StandardScaler().fit_transform(wine.data)
points = PCA(n_components=2).fit_transform(scaled_features)

model = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = model.fit_predict(scaled_features)

plt.scatter(points[:, 0], points[:, 1], c=clusters, cmap="viridis")
plt.xlabel("Principal component 1")
plt.ylabel("Principal component 2")
plt.title("Wine data grouped by k-means cluster")
plt.show()

# %% [markdown]
# ## Exercises
#
# 1. Try `n_clusters=2`, `3`, `4`, and `5`.
# 2. Record the model's `inertia_` for each choice.
# 3. Make a small line chart of cluster count versus inertia.
# 4. Explain why scaling matters before clustering.
# 5. Explain what PCA helps you visualize.
# 6. Choose a cluster count and justify it.

# %%
# TODO: compare multiple cluster counts and chart their inertia values.

# %% [markdown]
# ## Reflection
#
# - Scaling matters because: TODO
# - PCA is useful because: TODO
# - My chosen cluster count is: TODO
